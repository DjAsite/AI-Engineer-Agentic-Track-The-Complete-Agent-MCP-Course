# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not found.")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI

# %%
openai = OpenAI()

# %%
# First create the messages:
query = "Pick a business area that might be worth exploring for an Agentic AI opportunity."
messages = [{"role": "user", "content": query}]

# %%
# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# %%
# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)
# Out:
# One promising business area for exploring an Agentic AI opportunity is **personalized healthcare**. This sector encompasses various aspects, including patient management, treatment personalization, and health monitoring. Here are a few specific avenues within personalized healthcare where Agentic AI could make a significant impact:
#
# 1. **AI-Powered Health Assistants**: Develop AI agents that can serve as virtual health assistants, providing personalized medical advice based on individual health data, history, and preferences. These agents could assist patients in managing their medications, diet, and exercise regimens while offering reminders for appointments and follow-ups.
#
# 2. **Telemedicine Optimization**: Create intelligent AI systems that can triage patient inquiries in telemedicine platforms, triaging conditions based on symptoms entered by the patient. This would streamline the process for healthcare providers, allowing for better allocation of time and resources.
#
# 3. **Predictive Analytics for Disease Prevention**: Utilize Agentic AI to analyze vast datasets from electronic health records and other sources to identify patterns that predict health risks in individuals or populations. By providing actionable insights, healthcare providers can implement preventive measures tailored to specific patient needs.
#
# 4. **Mental Health Support**: Develop AI-driven mental health chatbots that can provide real-time emotional support, monitor user mood and anxiety levels, and suggest coping strategies or when to seek professional help. This can be particularly beneficial for individuals with limited access to mental health resources.
#
# 5. **Personalized Treatment Plans**: Leverage AI to create and continually adjust personalized treatment plans based on real-time data from wearable devices, laboratory tests, and patient feedback. This would ensure that each patient receives the most effective care tailored specifically to their changing conditions.
#
# 6. **Clinical Decision Support**: Implement Agentic AI systems to assist doctors in making evidence-based decisions by providing real-time insights from high-quality medical literature and patient-specific data.
#
# The personalized healthcare field is ripe for innovation, and Agentic AI can play a pivotal role in enhancing patient outcomes, reducing costs, and improving the overall efficiency of healthcare systems.

# %%
from IPython.display import Markdown, display

# %%
display(Markdown(business_idea))
# Out:
# One promising business area for exploring an Agentic AI opportunity is **personalized healthcare**. This sector encompasses various aspects, including patient management, treatment personalization, and health monitoring. Here are a few specific avenues within personalized healthcare where Agentic AI could make a significant impact:
#
# 1. **AI-Powered Health Assistants**: Develop AI agents that can serve as virtual health assistants, providing personalized medical advice based on individual health data, history, and preferences. These agents could assist patients in managing their medications, diet, and exercise regimens while offering reminders for appointments and follow-ups.
#
# 2. **Telemedicine Optimization**: Create intelligent AI systems that can triage patient inquiries in telemedicine platforms, triaging conditions based on symptoms entered by the patient. This would streamline the process for healthcare providers, allowing for better allocation of time and resources.
#
# 3. **Predictive Analytics for Disease Prevention**: Utilize Agentic AI to analyze vast datasets from electronic health records and other sources to identify patterns that predict health risks in individuals or populations. By providing actionable insights, healthcare providers can implement preventive measures tailored to specific patient needs.
#
# 4. **Mental Health Support**: Develop AI-driven mental health chatbots that can provide real-time emotional support, monitor user mood and anxiety levels, and suggest coping strategies or when to seek professional help. This can be particularly beneficial for individuals with limited access to mental health resources.
#
# 5. **Personalized Treatment Plans**: Leverage AI to create and continually adjust personalized treatment plans based on real-time data from wearable devices, laboratory tests, and patient feedback. This would ensure that each patient receives the most effective care tailored specifically to their changing conditions.
#
# 6. **Clinical Decision Support**: Implement Agentic AI systems to assist doctors in making evidence-based decisions by providing real-time insights from high-quality medical literature and patient-specific data.
#
# The personalized healthcare field is ripe for innovation, and Agentic AI can play a pivotal role in enhancing patient outcomes, reducing costs, and improving the overall efficiency of healthcare systems.

# %%
# Second exercice: Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.

# First create the messages:

prompt = f"Please present a pain-point in that industry, something challenging that might be ripe for an Agentic solution for it in that industry: {business_idea}"
messages = [{"role": "user", "content": prompt}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# %%
painpoint = response.choices[0].message.content
 
# print(painpoint) 
display(Markdown(painpoint))
# Out:
# One significant pain point in the personalized healthcare industry is the challenge of **data integration and interoperability** among various health information systems. Healthcare providers often rely on disparate systems that store patient data in different formats, making it difficult to achieve a comprehensive view of a patient's health history. This fragmentation can lead to several key challenges:
#
# ### Fragmentation of Patient Data
#
# 1. **Limited Accessibility**: Healthcare providers may not have immediate access to a patient's complete medical history, including previous diagnoses, treatments, medications, and lab results. This lack of visibility can hinder their ability to make informed decisions, particularly in urgent or complex situations.
#
# 2. **Inconsistent Data Quality**: Different systems may have varying standards for data entry and measurement, leading to inconsistencies in the information collected. This poor data quality can impact clinical decision-making and patient treatment plans.
#
# 3. **Increased Administrative Burden**: Healthcare professionals often spend significant time manually retrieving and reconciling information from multiple systems, resulting in increased administrative costs and reduced time for patient care.
#
# 4. **Poor Patient Engagement**: Patients may have difficulty accessing their own health data, which can leave them feeling disconnected from their treatment process. This disconnect can lead to lower adherence to treatment plans and missed opportunities for patient education.
#
# ### Opportunity for Agentic Solution
#
# An Agentic AI solution could address these challenges by developing an **integrated health data platform**. This platform could leverage advanced AI algorithms to:
#
# - **Aggregate and Normalize Data**: Automatically pull and normalize data from various electronic health record (EHR) systems and wearable health devices, creating a unified health profile for each patient.
#
# - **Enhance Interoperability**: Utilize standardized APIs and protocols that bridge gaps between disparate systems, facilitating smoother communication and data exchange among healthcare providers.
#
# - **Empower Patients**: Provide patients with a comprehensive view of their health data through a user-friendly application, empowering them to engage more actively in their healthcare.
#
# - **Real-time Data Insights**: Employ AI to analyze the integrated data continuously and offer actionable insights, alerts, or reminders to both healthcare providers and patients, thereby enhancing treatment adherence and outcomes.
#
# By addressing the fragmentation of patient data through an Agentic AI solution, the personalized healthcare industry not only stands to improve operational efficiencies but also enhance patient care and engagement, ultimately contributing to better health outcomes.

# %%
# third exercice: Finally have 3 third LLM call propose the Agentic AI solution.

# First create the messages:

prompt3 = f"Please come up with a proposal for the Agentic AI solution to address this business painpoint:  {painpoint}"
messages = [{"role": "user", "content": prompt3}]

# %%
# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# %%
# Then read the business idea:

answer3=response.choices[0].message.content
# print(painpoint) 
display(Markdown(answer3))
# Out:
# ### Proposal for an Agentic AI Solution: Integrated Health Data Platform
#
# #### Executive Summary
# The personalized healthcare industry is facing significant challenges related to data integration and interoperability among various health information systems. Fragmentation of patient data has led to limited accessibility, inconsistent data quality, an increased administrative burden on healthcare professionals, and inadequate patient engagement. This proposal outlines a comprehensive solution using Agentic AI technology to develop an integrated health data platform aimed at overcoming these obstacles and enhancing the overall healthcare experience.
#
# #### Objectives
# 1. **Create a Unified Health Profile**: Consolidate patient data from disparate sources into a single view, enabling healthcare providers to make informed decisions.
# 2. **Improve Data Interoperability**: Utilize standardized APIs and protocols to facilitate seamless data exchange across different systems.
# 3. **Enhance Patient Engagement**: Empower patients by providing them access to their complete health data and actionable insights.
# 4. **Optimize Clinical Decision-Making**: Leverage AI analytics to improve data quality and generate real-time insights for healthcare providers.
#
# #### Solution Features
#
# 1. **Data Aggregation and Normalization**
#    - The platform will automatically integrate data from various electronic health record (EHR) systems, wearables, and health monitoring devices.
#    - Utilizing AI algorithms, it will clean, normalize, and standardize data formats to create a comprehensive health profile for each patient.
#
# 2. **Seamless Interoperability**
#    - Implement standardized APIs compliant with healthcare data sharing protocols (e.g., FHIR, HL7).
#    - Foster partnerships with EHR vendors and other stakeholders to ensure broad compatibility and adherence to data exchange standards.
#
# 3. **Patient-Centric Interface**
#    - Develop a user-friendly mobile and web application where patients can access their health information easily.
#    - Include features like personalized health insights, reminders for medications and upcoming appointments, and educational resources to promote proactive health management.
#
# 4. **Real-time Data Insights and Alerts**
#    - Use machine learning algorithms to analyze integrated data continuously, identifying patterns that may indicate health risks or treatment non-adherence.
#    - Provide alerts to healthcare providers regarding potential issues, enabling timely interventions and personalized care plans.
#
# 5. **Decision Support Tools for Providers**
#    - Offer AI-powered decision support tools that assist healthcare providers in assessing patient needs based on their comprehensive health profiles.
#    - Enable predictive analytics to optimize treatment plans and improve clinical outcomes.
#
# #### Implementation Strategy
#
# 1. **Phase 1: Pilot Program**
#    - Initiate a pilot program with selected healthcare institutions to test the integrated health data platform, addressing any initial challenges and gathering feedback from users.
#
# 2. **Phase 2: Platform Development and Integration**
#    - Refine the platform based on pilot feedback and develop necessary partnerships for broader EHR integration.
#    - Focus on user experience design to ensure ease of access and usability for both healthcare providers and patients.
#
# 3. **Phase 3: Full-scale Deployment**
#    - Roll out the integrated platform to more healthcare providers and patients, accompanied by training sessions and support resources to maximize adoption and efficacy.
#
# 4. **Phase 4: Continuous Improvement and Innovation**
#    - Regularly update the platform based on user feedback, technological advancements, and regulatory changes in healthcare data management.
#
# #### Expected Outcomes
# - **Improved Accessibility**: Enhanced visibility into comprehensive patient histories, enabling informed clinical decisions.
# - **Higher Data Quality**: Increased consistency in data collection and reporting, positively impacting clinical outcomes.
# - **Reduced Administrative Workload**: Significant decrease in time and effort spent on data retrieval and reconciliation by healthcare professionals.
# - **Enhanced Patient Engagement**: Increased patient involvement in their own healthcare, leading to better adherence to treatment plans and overall health management.
#
# #### Conclusion
# By implementing an integrated health data platform powered by Agentic AI, we can effectively address the current challenges of data fragmentation in the healthcare industry. This solution will not only streamline operations but also elevate the standard of patient care, promote patient engagement, and ultimately lead to better health outcomes. We invite stakeholders in the healthcare industry to collaborate in bringing this innovative solution to life, paving the way for a more connected and efficient healthcare system.
